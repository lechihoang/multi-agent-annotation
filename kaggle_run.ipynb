# %% [markdown]
# # Multi-Agent Annotation Runner trên Kaggle
# Notebook này giúp bạn chạy hệ thống gán nhãn tự động trên Kaggle để không tốn tài nguyên máy cá nhân.

# %%
# 1. Clone Source Code từ GitHub của bạn
# !git clone https://github.com/lechihoang/multi-agent-annotation.git

# Di chuyển vào thư mục dự án
# %cd multi-agent-annotation

# Cài đặt các thư viện từ pyproject.toml
# !pip install -q -e .

# %%
import os

# 2. Cấu hình NVIDIA API Key
# Nhập API Key của bạn vào đây (Kaggle có tính năng Secret, nhưng dùng biến môi trường cho lẹ)
os.environ["NVIDIA_API_KEY"] = "nvapi-thay-bang-key-cua-ban-vao-day"

# %%
# 3. Chạy quá trình gán nhãn
# Đổi tên file input/output theo ý muốn
# !python run.py --input data/ViCTSD_unlabeled.csv --output data/ViCTSD_annotated.csv
